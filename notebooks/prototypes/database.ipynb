# %%
import os
import sys
from pathlib import Path

ROOT = Path(os.path.abspath('')).resolve().parents[2]
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))


import nvitk as nv
from nvitk import db
import pandas as pd

# %% [markdown]
# Build DB

# %%
from nvitk.db import DataRepo, import_pesabrain_source, list_pesabrain_sources

db_base = Path("/data_local/LabVF/PESA-Brain/DB/DB")
repo = DataRepo("~/nvitk/dataset", auto_scaffold=True, use_sqlite=True)

# %%
# res = import_pesabrain_source(
#     repo,
#     db_base,
#     "PESABrain_All_IDs.xlsx",
#     sheet="Sheet1",
#     source_kind="subject_ids",
#     build_sqlite_index=True,
# )

# res = import_pesabrain_source(
#     repo,
#     db_base,
#     "PESABrain_All_4DFlow_IDs.xlsx",
#     sheet="Sheet1",
#     source_kind="subject_ids",
#     build_sqlite_index=True,
# )

# import_pesabrain_source(
#     repo,
#     db_base,
#     "PESABrain_SubjectCatalog_AllXNAT_20260216.xlsx",
#     sheet="Datos",
#     source_kind="subject_catalog",
#     build_sqlite_index=True,
# )

# import_pesabrain_source(
#     repo,
#     db_base,
#     "PESABrain_Clinical_20260216.xlsx",
#     sheet="Sheet1",
#     source_kind="clinical_wide",
#     build_sqlite_index=True,
# )

# import_pesabrain_source(repo, db_base, "PESABrain_APOE_20260318.xlsx", sheet="Sheet1", source_kind="clinical_wide", build_sqlite_index=True)
# import_pesabrain_source(repo, db_base, "PESABrain_TAC_20260318.xlsx", sheet="Sheet1", source_kind="clinical_wide", build_sqlite_index=True)
# import_pesabrain_source(repo, db_base, "PESABrain_Echography_CarotidePlaque_20260216.xlsx", sheet="Sheet1", source_kind="clinical_wide", build_sqlite_index=True)

# import_pesabrain_source(repo, db_base, "PESABrain_4DFlow_LocalizedPI_20260216.xlsx", sheet="PESABrain_AnalysisDB_Batch1", source_kind="image_wide", build_sqlite_index=True)
# import_pesabrain_source(repo, db_base, "PESABrain_4DFlow_LocalizedTimeAvgFlow_20260216.xlsx", sheet="PESABrain_AnalysisDB_Batch1", source_kind="image_wide", build_sqlite_index=True)

# import_pesabrain_source(repo, db_base, "PESABrain_4DFlow_LocalizedTimeseriesFlow_Wide_20260216.xlsx", sheet="Datos", source_kind="image_timeseries_wide", build_sqlite_index=True)

# import_pesabrain_source(repo, db_base, "PESABrain_ASLPerfusion_ThrMeanCBF_20260216.xlsx", sheet="Sheet1", source_kind="image_wide", build_sqlite_index=True)
# import_pesabrain_source(repo, db_base, "PESABrain_ASLPerfusion_VascularAtlas_MeanCBF_20260216.xlsx", sheet="Sheet1", source_kind="image_wide", build_sqlite_index=True)
# import_pesabrain_source(
#     repo,
#     db_base,
#     "PESABrain_ASLPerfusion_CovCBF_20260216.xlsx",
#     sheet="Sheet1",
#     source_kind="image_wide",
#     build_sqlite_index=True,
# )
# Out:
# {'filename': 'PESABrain_ASLPerfusion_CovCBF_20260216.xlsx',
#  'sheet': 'Sheet1',
#  'source_kind': 'image_wide',
#  'result':          subject_uid  session_id modality      region_id   region_label  \
#  0       PESA10017225  BMRI613225      asl     patient_id     patient_id
#  1        PESA1002001    IA706156      asl     patient_id     patient_id
#  2         PESA100489  BMRI649274      asl     patient_id     patient_id
#  3       PESA10055241  BMRI872431      asl     patient_id     patient_id
#  4        PESA1006009  BMRI923674      asl     patient_id     patient_id
#  ...              ...         ...      ...            ...            ...
#  113401   PESA9935104  BMRI881199      asl  ctx_rh_insula  ctx-rh-insula
#  113402   PESA9947716  BMRI447102      asl  ctx_rh_insula  ctx-rh-insula
#  113403   PESA9954025  BMRI971103      asl  ctx_rh_insula  ctx-rh-insula
#  113404    PESA996004    IA192427      asl  ctx_rh_insula  ctx-rh-insula
#  113405   PESA9972964  BMRI105334      asl  ctx_rh_insula  ctx-rh-insula
#
#          frame_index variable_id  value_num    value_text  unit  ...  \
#  0              <NA>     cov_cbf        NaN  PESA10017225  <NA>  ...
#  1              <NA>     cov_cbf        NaN   PESA1002001  <NA>  ...
#  2              <NA>     cov_cbf        NaN    PESA100489  <NA>  ...
#  3              <NA>     cov_cbf        NaN  PESA10055241  <NA>  ...
#  4              <NA>     cov_cbf        NaN   PESA1006009  <NA>  ...
#  ...             ...         ...        ...           ...   ...  ...
#  113401         <NA>     cov_cbf   0.484859          <NA>  <NA>  ...
#  113402         <NA>     cov_cbf   0.415895          <NA>  <NA>  ...
#  113403         <NA>     cov_cbf   0.515698          <NA>  <NA>  ...
#  113404         <NA>     cov_cbf   0.694183          <NA>  <NA>  ...
#  113405         <NA>     cov_cbf   0.427383          <NA>  <NA>  ...
#
#                                   pipeline_name pipeline_id qc_status  \
#  0       PESABrain_ASLPerfusion_CovCBF_20260216      asl_v1      <NA>
#  1       PESABrain_ASLPerfusion_CovCBF_20260216      asl_v1      <NA>
#  2       PESABrain_ASLPerfusion_CovCBF_20260216      asl_v1      <NA>
#  3       PESABrain_ASLPerfusion_CovCBF_20260216      asl_v1      <NA>
#  4       PESABrain_ASLPerfusion_CovCBF_20260216      asl_v1      <NA>
#  ...                                        ...         ...       ...
#  113401  PESABrain_ASLPerfusion_CovCBF_20260216      asl_v1      <NA>
#  113402  PESABrain_ASLPerfusion_CovCBF_20260216      asl_v1      <NA>
#  113403  PESABrain_ASLPerfusion_CovCBF_20260216      asl_v1      <NA>
#  113404  PESABrain_ASLPerfusion_CovCBF_20260216      asl_v1      <NA>
#  113405  PESABrain_ASLPerfusion_CovCBF_20260216      asl_v1      <NA>
#
#         source_asset                                    source_table  \
#  0              <NA>  PESABrain_ASLPerfusion_CovCBF_20260216::Sheet1
#  1              <NA>  PESABrain_ASLPerfusion_CovCBF_20260216::Sheet1
#  2              <NA>  PESABrain_ASLPerfusion_CovCBF_20260216::Sheet1
#  3              <NA>  PESABrain_ASLPerfusion_CovCBF_20260216::Sheet1
#  4              <NA>  PESABrain_ASLPerfusion_CovCBF_20260216::Sheet1
#  ...             ...                                             ...
#  113401         <NA>  PESABrain_ASLPerfusion_CovCBF_20260216::Sheet1
#  113402         <NA>  PESABrain_ASLPerfusion_CovCBF_20260216::Sheet1
#  113403         <NA>  PESABrain_ASLPerfusion_CovCBF_20260216::Sheet1
#  113404         <NA>  PESABrain_ASLPerfusion_CovCBF_20260216::Sheet1
#  113405         <NA>  PESABrain_ASLPerfusion_CovCBF_20260216::Sheet1
#
#                                          source_file source_sheet  \
#  0       PESABrain_ASLPerfusion_CovCBF_20260216.xlsx       Sheet1
#  1       PESABrain_ASLPerfusion_CovCBF_20260216.xlsx       Sheet1
#  2       PESABrain_ASLPerfusion_CovCBF_20260216.xlsx       Sheet1
#  3       PESABrain_ASLPerfusion_CovCBF_20260216.xlsx       Sheet1
#  4       PESABrain_ASLPerfusion_CovCBF_20260216.xlsx       Sheet1
#  ...                                             ...          ...
#  113401  PESABrain_ASLPerfusion_CovCBF_20260216.xlsx       Sheet1
#  113402  PESABrain_ASLPerfusion_CovCBF_20260216.xlsx       Sheet1
#  113403  PESABrain_ASLPerfusion_CovCBF_20260216.xlsx       Sheet1
#  113404  PESABrain_ASLPerfusion_CovCBF_20260216.xlsx       Sheet1
#  113405  PESABrain_ASLPerfusion_CovCBF_20260216.xlsx       Sheet1
#
#          source_column                 source_batch_id measured_at
#  0          patient_id  pesabrain_20260411T113803+0000         NaT
#  1          patient_id  pesabrain_20260411T113803+0000         NaT
#  2          patient_id  pesabrain_20260411T113803+0000         NaT
#  3          patient_id  pesabrain_20260411T113803+0000         NaT
#  4          patient_id  pesabrain_20260411T113803+0000         NaT
#  ...               ...                             ...         ...
#  113401  ctx-rh-insula  pesabrain_20260411T113803+0000         NaT
#  113402  ctx-rh-insula  pesabrain_20260411T113803+0000         NaT
#  113403  ctx-rh-insula  pesabrain_20260411T113803+0000         NaT
#  113404  ctx-rh-insula  pesabrain_20260411T113803+0000         NaT
#  113405  ctx-rh-insula  pesabrain_20260411T113803+0000         NaT
#
#  [113406 rows x 21 columns],
#  'subjects':        subject_uid primary_patient_id primary_seqn     sex birth_date notes  \
#  0          PESA841            PESA841           28    Male        NaT  <NA>
#  1          PESA900            PESA900           29  Female        NaT  <NA>
#  2         PESA3481           PESA3481           58    Male        NaT  <NA>
#  3         PESA3600           PESA3600           59    Male        NaT  <NA>
#  4         PESA4225           PESA4225           64  Female        NaT  <NA>
#  ...            ...                ...          ...     ...        ...   ...
#  1419    PESA894916         PESA894916          NaN     NaN        NaT  <NA>
#  1420  PESA17089956       PESA17089956          NaN     NaN        NaT  <NA>
#  1421     PESA31329          PESA31329          NaN     NaN        NaT  <NA>
#  1422      PESA5476           PESA5476          NaN     NaN        NaT  <NA>
#  1423  PESA13461561       PESA13461561          NaN     NaN        NaT  <NA>
#
#         source_batch_id                 updated_at
#  0     derived_subjects  2026-04-11T11:38:17+00:00
#  1     derived_subjects  2026-04-11T11:38:17+00:00
#  2     derived_subjects  2026-04-11T11:38:17+00:00
#  3     derived_subjects  2026-04-11T11:38:17+00:00
#  4     derived_subjects  2026-04-11T11:38:17+00:00
#  ...                ...                        ...
#  1419  derived_subjects  2026-04-11T11:38:33+00:00
#  1420  derived_subjects  2026-04-11T11:38:33+00:00
#  1421  derived_subjects  2026-04-11T11:38:33+00:00
#  1422  derived_subjects  2026-04-11T11:38:33+00:00
#  1423  derived_subjects  2026-04-11T11:38:33+00:00
#
#  [1424 rows x 8 columns]}

# %%
# repo.drop_all_tables()

# %%
# repo.get("source_tables").sort_values(["source_file", "source_sheet", "source_kind"])

# %%
repo.clinical(
    variables=["BPXSYM", "BMI", "tacsctot_group"],
    filters={
        # "subject_uid": ["PESA10407076", "PESA16016004"],
        # "bmi": {"$ge": 27, "$lt": 30}
    },
    wide=True,
)
# Out:
#        subject_uid visit_id        bmi bpxsym tacsctot_group
# 0     PESA10017225        4  30.119402  130.0             g1
# 1       PESA100489        4  22.662709  128.0             g0
# 2     PESA10048900        4        NaN  150.0             g1
# 3     PESA10055241        4  27.398176  117.0             g1
# 4      PESA1006009        4  27.968016  124.0             g0
# ...            ...      ...        ...    ...            ...
# 996    PESA9928801        4  27.041644  104.0             g0
# 997    PESA9935104        4  19.896194  122.0             g0
# 998    PESA9947716        4  29.757785  114.0             g1
# 999    PESA9954025        4  23.875659  126.0             g1
# 1000   PESA9972964        4  19.322185  109.0             g0
#
# [1001 rows x 5 columns]

# %%
repo.image(
    modality="4dflow",
    # pipeline="pesabrain_4dflow_current",
    variables=["flow_mean", 'pi'],
    regions=["right_ica", "left_ica", 'basilar'],
    wide=True,
    use_sqlite=True,
)
# Out:
#       subject_uid  session_id  4dflow__basilar__flow_mean__4dflow_v1  \
# 0     PESA1006009  BMRI923674                             184.510389
# 1    PESA10061584  BMRI287356                             182.850943
# 2    PESA10067929  BMRI965424                             228.640571
# 3    PESA10086976  BMRI859483                             251.966084
# 4    PESA10112400  BMRI465140                             151.450536
# ..            ...         ...                                    ...
# 343   PESA9897316  BMRI994162                             178.221377
# 344   PESA9928801  BMRI487416                              87.832792
# 345   PESA9935104  BMRI881199                             245.827435
# 346   PESA9947716  BMRI447102                             309.712580
# 347   PESA9972964  BMRI105334                             183.211070
#
#      4dflow__basilar__pi__4dflow_v1  4dflow__left_ica__flow_mean__4dflow_v1  \
# 0                          0.791092                              267.035802
# 1                          0.819871                               94.844843
# 2                          0.810012                              323.586469
# 3                          0.657827                              303.364359
# 4                          0.657464                              325.856177
# ..                              ...                                     ...
# 343                        0.674136                              283.497145
# 344                        0.567656                              314.992869
# 345                        0.719752                              352.592480
# 346                        0.857074                              350.185589
# 347                        0.688649                              301.500929
#
#      4dflow__left_ica__pi__4dflow_v1  4dflow__right_ica__flow_mean__4dflow_v1  \
# 0                           0.701133                               281.351906
# 1                           0.639911                               207.560577
# 2                           0.773645                               355.117301
# 3                           0.540127                                 0.814246
# 4                           0.707761                               330.478438
# ..                               ...                                      ...
# 343                         0.709040                               262.646432
# 344                         0.850857                               370.991649
# 345                         0.753206                               199.660541
# 346                         0.807655                               358.434131
# 347                         0.668324                               253.431541
#
#      4dflow__right_ica__pi__4dflow_v1
# 0                            0.727263
# 1                            0.698219
# 2                            0.796976
# 3                            0.847596
# 4                            0.791426
# ..                                ...
# 343                          0.782386
# 344                          0.870882
# 345                          0.735158
# 346                          0.811330
# 347                          0.742674
#
# [348 rows x 8 columns]

# %%
repo.image(
    modality="4dflow",
    # pipeline="pesabrain_4dflow_current",
    variables=["flow_tseries"],
    regions=["right_ica", "left_ica", 'basi'],
    wide=True,
    use_sqlite=True,
)
# Out:
#       subject_uid session_id  4dflow__basi__0__flow_tseries__4dflow_v1  \
# 0     PESA1006009                                           171.740742
# 1    PESA10061584                                           167.251668
# 2    PESA10067929                                           234.015326
# 3    PESA10086976                                           200.100117
# 4    PESA10112400                                           139.311733
# ..            ...        ...                                       ...
# 337   PESA9897316                                           146.445465
# 338   PESA9928801                                            78.387072
# 339   PESA9935104                                           229.139428
# 340   PESA9947716                                           253.525257
# 341   PESA9972964                                           197.611041
#
#      4dflow__basi__10__flow_tseries__4dflow_v1  \
# 0                                   262.681961
# 1                                   251.961823
# 2                                   331.168985
# 3                                   237.502127
# 4                                   205.431976
# ..                                         ...
# 337                                 189.702344
# 338                                 118.553166
# 339                                 351.813755
# 340                                 273.990383
# 341                                 245.183058
#
#      4dflow__basi__11__flow_tseries__4dflow_v1  \
# 0                                   237.725158
# 1                                   186.144733
# 2                                   309.251060
# 3                                   246.950941
# 4                                   183.801470
# ..                                         ...
# 337                                 170.771270
# 338                                 109.357817
# 339                                 317.140303
# 340                                 287.376165
# 341                                 252.565899
#
#      4dflow__basi__12__flow_tseries__4dflow_v1  \
# 0                                   188.848443
# 1                                   178.125043
# 2                                   264.493818
# 3                                   232.032981
# 4                                   159.936533
# ..                                         ...
# 337                                 172.337880
# 338                                  90.608840
# 339                                 256.308432
# 340                                 289.021425
# 341                                 241.381731
#
#      4dflow__basi__13__flow_tseries__4dflow_v1  \
# 0                                   191.011362
# 1                                   174.001665
# 2                                   242.809982
# 3                                   216.727839
# 4                                   156.501975
# ..                                         ...
# 337                                 168.572130
# 338                                  91.994212
# 339                                 260.468359
# 340                                 284.843245
# 341                                 212.511535
#
#      4dflow__basi__14__flow_tseries__4dflow_v1  \
# 0                                   189.220390
# 1                                   166.416178
# 2                                   229.040794
# 3                                   218.705420
# 4                                   155.314536
# ..                                         ...
# 337                                 159.571881
# 338                                  86.635509
# 339                                 243.036089
# 340                                 276.262808
# 341                                 210.013647
#
#      4dflow__basi__1__flow_tseries__4dflow_v1  \
# 0                                  168.193645
# 1                                  155.436301
# 2                                  209.301810
# 3                                  181.868849
# 4                                  126.335349
# ..                                        ...
# 337                                146.135516
# 338                                 73.397763
# 339                                203.757019
# 340                                221.942196
# 341                                180.883598
#
#      4dflow__basi__2__flow_tseries__4dflow_v1  \
# 0                                  152.294641
# 1                                  151.897402
# 2                                  190.483975
# 3                                  175.903559
# 4                                  122.262626
# ..                                        ...
# 337                                138.917656
# 338                                 71.107993
# 339                                207.432761
# 340                                203.814025
# 341                                169.744234
#
#      4dflow__basi__3__flow_tseries__4dflow_v1  \
# 0                                  138.217177
# 1                                  130.579791
# 2                                  179.451871
# 3                                  195.263457
# 4                                  115.729229
# ..                                        ...
# 337                                132.200232
# 338                                 69.733021
# 339                                199.516983
# 340                                199.518857
# 341                                160.409818
#
#      4dflow__basi__4__flow_tseries__4dflow_v1  \
# 0                                  136.751847
# 1                                  123.068390
# 2                                  173.877940
# 3                                  289.014559
# 4                                  114.442914
# ..                                        ...
# 337                                127.832479
# 338                                 69.948456
# 339                                187.837157
# 340                                273.705168
# 341                                147.973294
#
#      4dflow__basi__5__flow_tseries__4dflow_v1  \
# 0                                  130.361080
# 1                                  117.425623
# 2                                  162.381248
# 3                                  323.399076
# 4                                  112.360876
# ..                                        ...
# 337                                170.140100
# 338                                 68.694377
# 339                                174.878869
# 340                                464.965525
# 341                                139.340687
#
#      4dflow__basi__6__flow_tseries__4dflow_v1  \
# 0                                  120.433002
# 1                                  159.254665
# 2                                  145.967445
# 3                                  341.653547
# 4                                  114.743800
# ..                                        ...
# 337                                240.659351
# 338                                 70.771401
# 339                                180.644660
# 340                                454.760971
# 341                                129.881787
#
#      4dflow__basi__7__flow_tseries__4dflow_v1  \
# 0                                  160.840273
# 1                                  256.388626
# 2                                  177.177801
# 3                                  332.864256
# 4                                  146.442618
# ..                                        ...
# 337                                236.923871
# 338                                 97.363837
# 339                                228.866200
# 340                                426.791239
# 341                                132.475276
#
#      4dflow__basi__8__flow_tseries__4dflow_v1  \
# 0                                  252.938347
# 1                                  267.339821
# 2                                  264.656296
# 3                                  311.874561
# 4                                  207.208228
# ..                                        ...
# 337                                247.977991
# 338                                114.649208
# 339                                321.558523
# 340                                386.633577
# 341                                126.397777
#
#      4dflow__basi__9__flow_tseries__4dflow_v1
# 0                                  266.397772
# 1                                  257.472410
# 2                                  315.530205
# 3                                  275.629978
# 4                                  211.934180
# ..                                        ...
# 337                                225.132494
# 338                                114.833064
# 339                                325.012980
# 340                                348.537855
# 341                                201.792669
#
# [342 rows x 17 columns]

# %%
repo.image(
    modality="asl",
    variables=['mean_cbf'],
    # regions=["right_ica"],
    atlas="vascular-8",
    wide=True,
    use_sqlite=True,
)
# Out:
#        subject_uid  session_id  asl__left_aca_8__mean_cbf__asl_v1  \
# 0                     IA815287                          45.831087
# 1     PESA10017225  BMRI613225                          54.748315
# 2      PESA1002001    IA706156                          45.890711
# 3       PESA100489  BMRI649274                          69.372262
# 4     PESA10055241  BMRI872431                          48.728630
# ...            ...         ...                                ...
# 1354   PESA9935104  BMRI881199                          52.431084
# 1355   PESA9947716  BMRI447102                          61.730753
# 1356   PESA9954025  BMRI971103                          50.173566
# 1357    PESA996004    IA192427                          35.530079
# 1358   PESA9972964  BMRI105334                          56.058626
#
#       asl__left_basilar_8__mean_cbf__asl_v1  \
# 0                                 40.621590
# 1                                 53.706869
# 2                                 43.595341
# 3                                 73.106089
# 4                                 51.617259
# ...                                     ...
# 1354                              40.572026
# 1355                              49.490786
# 1356                              59.817856
# 1357                              27.512319
# 1358                              45.547853
#
#       asl__left_mca_8__mean_cbf__asl_v1  asl__left_pca_8__mean_cbf__asl_v1  \
# 0                             47.245653                          35.603938
# 1                             55.329698                          52.413142
# 2                             50.949984                          44.144234
# 3                             73.012827                          66.389724
# 4                             51.208784                          43.545062
# ...                                 ...                                ...
# 1354                          54.236169                          43.115527
# 1355                          66.492889                          50.254449
# 1356                          53.479352                          51.124338
# 1357                          36.425947                          27.105437
# 1358                          58.761334                          48.897040
#
#       asl__right_aca_8__mean_cbf__asl_v1  \
# 0                              47.587176
# 1                              55.075685
# 2                              46.676598
# 3                              70.515337
# 4                              46.788938
# ...                                  ...
# 1354                           50.796183
# 1355                           66.573847
# 1356                           51.770626
# 1357                           32.436489
# 1358                           56.701499
#
#       asl__right_basilar_8__mean_cbf__asl_v1  \
# 0                                  39.798200
# 1                                  55.741001
# 2                                  43.494788
# 3                                  70.898637
# 4                                  48.530094
# ...                                      ...
# 1354                               38.552160
# 1355                               50.701696
# 1356                               59.725848
# 1357                               29.319548
# 1358                               46.652231
#
#       asl__right_mca_8__mean_cbf__asl_v1  asl__right_pca_8__mean_cbf__asl_v1  \
# 0                              48.180616                           36.658410
# 1                              55.305353                           50.399999
# 2                              50.105159                           42.889667
# 3                              72.683254                           66.693302
# 4                              49.396042                           42.430235
# ...                                  ...                                 ...
# 1354                           54.130418                           40.179098
# 1355                           72.198803                           49.731519
# 1356                           50.970979                           51.650691
# 1357                           31.538392                           27.172000
# 1358                           57.912745                           47.255383
#
#       asl__watershed_8__mean_cbf__asl_v1
# 0                              41.674001
# 1                              45.768453
# 2                              40.066280
# 3                              54.169724
# 4                              39.087144
# ...                                  ...
# 1354                           46.629408
# 1355                           55.293241
# 1356                           43.565898
# 1357                           26.031640
# 1358                           48.016116
#
# [1359 rows x 11 columns]

# %%
clinical = repo.clinical(
    variables=["BPXSYM", "BMI", "tacsctot_group"],
    filters={"subject_uid": ["PESA10407076", "PESA16016004"]},
    wide=True,
)

hemo = repo.image(
    modality="4dflow",
    variables=["flow_mean", 'pi'],
    regions=["right_ica", "left_ica"],
    pipeline="legacy",
    wide=True,
)

report_df = repo.join([clinical, hemo])
report_df.head()
# Out:
#     subject_uid visit_id        bmi bpxsym tacsctot_group  session_id  \
# 0  PESA10407076        4  29.011226  137.0             g1  BMRI395267
# 1  PESA16016004        4  25.099502  121.0             g1  BMRI611724
#
#    4dflow__left_ica__flow_mean__4dflow_v1  4dflow__left_ica__pi__4dflow_v1  \
# 0                              336.984932                         0.698981
# 1                              438.522579                         0.929726
#
#    4dflow__right_ica__flow_mean__4dflow_v1  4dflow__right_ica__pi__4dflow_v1
# 0                               346.493410                          0.719224
# 1                               397.337101                          0.939473

# %%
# repo.build_sqlite_index()
# Out:
# PosixPath('/home/imarcoss/nvitk/dataset/cache/index.sqlite')

# %%
# import_pesabrain_source(
#     repo,
#     db_base,
#     "PESABrain_ASLPerfusion_CovCBF_20260216.xlsx",
#     sheet="Sheet1",
#     source_kind="image_wide",
# )

repo.image(
    modality="asl",
    variables=["cov_cbf"],
    atlas="desikan",
    wide=True,
)
# Out:
#        subject_uid  session_id  asl__ctx_left_anterior_cingulate__cov_cbf  \
# 0     PESA10017225  BMRI613225                                   0.452060
# 1      PESA1002001    IA706156                                   0.395617
# 2       PESA100489  BMRI649274                                   0.527712
# 3     PESA10055241  BMRI872431                                   0.426895
# 4      PESA1006009  BMRI923674                                   0.518955
# ...            ...         ...                                        ...
# 1378   PESA9935104  BMRI881199                                   0.405067
# 1379   PESA9947716  BMRI447102                                   0.381084
# 1380   PESA9954025  BMRI971103                                   0.472588
# 1381    PESA996004    IA192427                                   0.827544
# 1382   PESA9972964  BMRI105334                                   0.408378
#
#       asl__ctx_left_frontal_lobe__cov_cbf  asl__ctx_left_hemisphere__cov_cbf  \
# 0                                0.472829                           0.560015
# 1                                0.544135                           0.611366
# 2                                0.543879                           0.643825
# 3                                0.448705                           0.553270
# 4                                0.533282                           0.563952
# ...                                   ...                                ...
# 1378                             0.473152                           0.518197
# 1379                             0.456018                           0.570185
# 1380                             0.493494                           0.565424
# 1381                             0.663378                           0.722074
# 1382                             0.504800                           0.579825
#
#       asl__ctx_left_occipital_lobe__cov_cbf  \
# 0                                  0.620081
# 1                                  0.576589
# 2                                  0.682902
# 3                                  0.661140
# 4                                  0.551462
# ...                                     ...
# 1378                               0.564974
# 1379                               0.597395
# 1380                               0.604163
# 1381                               0.682393
# 1382                               0.648434
#
#       asl__ctx_left_parietal_lobe__cov_cbf  \
# 0                                 0.590010
# 1                                 0.639490
# 2                                 0.716763
# 3                                 0.557523
# 4                                 0.546076
# ...                                    ...
# 1378                              0.534482
# 1379                              0.618159
# 1380                              0.582947
# 1381                              0.694752
# 1382                              0.597248
#
#       asl__ctx_left_temporal_lobe__cov_cbf  asl__ctx_lh_bankssts__cov_cbf  \
# 0                                 0.651455                       0.542885
# 1                                 0.700544                       0.587060
# 2                                 0.722049                       0.778027
# 3                                 0.694156                       0.601335
# 4                                 0.660492                       0.500050
# ...                                    ...                            ...
# 1378                              0.557154                       0.507536
# 1379                              0.685539                       0.589018
# 1380                              0.666161                       0.568104
# 1381                              0.808883                       0.643079
# 1382                              0.674092                       0.600755
#
#       asl__ctx_lh_caudalanteriorcingulate__cov_cbf  ...  \
# 0                                         0.287351  ...
# 1                                         0.353848  ...
# 2                                         0.402595  ...
# 3                                         0.287250  ...
# 4                                         0.318890  ...
# ...                                            ...  ...
# 1378                                      0.371898  ...
# 1379                                      0.299786  ...
# 1380                                      0.302939  ...
# 1381                                      0.571278  ...
# 1382                                      0.306917  ...
#
#       asl__ctx_rh_supramarginal__cov_cbf  asl__ctx_rh_temporalpole__cov_cbf  \
# 0                               0.501129                           0.579615
# 1                               0.552336                           0.528527
# 2                               0.504942                           0.607363
# 3                               0.424982                           0.799478
# 4                               0.492034                           0.734295
# ...                                  ...                                ...
# 1378                            0.460791                           0.549321
# 1379                            0.457169                           0.472424
# 1380                            0.495543                           0.600872
# 1381                            0.585958                           0.580459
# 1382                            0.555574                           0.599855
#
#       asl__ctx_rh_transversetemporal__cov_cbf  \
# 0                                    0.374256
# 1                                    0.370642
# 2                                    0.392171
# 3                                    0.355929
# 4                                    0.321753
# ...                                       ...
# 1378                                 0.170726
# 1379                                 0.316467
# 1380                                 0.289030
# 1381                                 0.434666
# 1382                                 0.337562
#
#       asl__ctx_right_anterior_cingulate__cov_cbf  \
# 0                                       0.390560
# 1                                       0.406422
# 2                                       0.490312
# 3                                       0.388077
# 4                                       0.464139
# ...                                          ...
# 1378                                    0.396846
# 1379                                    0.300117
# 1380                                    0.422153
# 1381                                    0.588588
# 1382                                    0.384505
#
#       asl__ctx_right_frontal_lobe__cov_cbf  \
# 0                                 0.464650
# 1                                 0.525181
# 2                                 0.534953
# 3                                 0.439817
# 4                                 0.502499
# ...                                    ...
# 1378                              0.494713
# 1379                              0.456946
# 1380                              0.484560
# 1381                              0.636693
# 1382                              0.499499
#
#       asl__ctx_right_hemisphere__cov_cbf  \
# 0                               0.557169
# 1                               0.583345
# 2                               0.636887
# 3                               0.533953
# 4                               0.548704
# ...                                  ...
# 1378                            0.556186
# 1379                            0.560157
# 1380                            0.545574
# 1381                            0.722169
# 1382                            0.566991
#
#       asl__ctx_right_occipital_lobe__cov_cbf  \
# 0                                   0.600517
# 1                                   0.574381
# 2                                   0.726292
# 3                                   0.620370
# 4                                   0.561752
# ...                                      ...
# 1378                                0.591173
# 1379                                0.573520
# 1380                                0.553304
# 1381                                0.655451
# 1382                                0.593799
#
#       asl__ctx_right_parietal_lobe__cov_cbf  \
# 0                                  0.584465
# 1                                  0.639043
# 2                                  0.683077
# 3                                  0.546580
# 4                                  0.525568
# ...                                     ...
# 1378                               0.569271
# 1379                               0.601857
# 1380                               0.561335
# 1381                               0.723059
# 1382                               0.574100
#
#       asl__ctx_right_temporal_lobe__cov_cbf  asl__ctx_whole_brain__cov_cbf
# 0                                  0.681216                       0.558625
# 1                                  0.626311                       0.597330
# 2                                  0.726770                       0.640423
# 3                                  0.650340                       0.543731
# 4                                  0.662551                       0.556577
# ...                                     ...                            ...
# 1378                               0.638182                       0.537029
# 1379                               0.688001                       0.566396
# 1380                               0.636993                       0.555460
# 1381                               0.810111                       0.724639
# 1382                               0.671367                       0.573412
#
# [1383 rows x 83 columns]

# %%
# Remove

# empty = repo.get("subject_ids").iloc[0:0]
# repo.write_table("subject_ids", empty, provenance={"importer": "undo batch {trial_id}"})

# empty = repo.get("clinical_measurements").iloc[0:0]
# repo.write_table("clinical_measurements", empty, provenance={"importer": "undo batch {trial_id}"})

# empty = repo.get("image_measurements").iloc[0:0]
# repo.write_table("image_measurements", empty, provenance={"importer": "undo batch {trial_id}"})

# src = repo.get("source_tables")
# src = src[src["source_batch_id"] != trial_id]
# repo.write_table(
#   "source_tables",
#   src,
#   provenance={"reason": f"undo batch {trial_id}"},
# )
# Out:
# PosixPath('/home/imarcoss/nvitk/notebooks/prototypes/dataset/tables/image_measurements.parquet')
