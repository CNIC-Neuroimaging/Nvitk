# %%
import os
import sys
from pathlib import Path
import pandas as pd
import numpy as np

ROOT = Path(os.path.abspath('')).resolve().parents[2]
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))


import nvitk as nv
from nvitk import db

# %%
tmp_vascular_att = pd.read_csv('/data_local/LabVF/PESA-Brain/DB/new_vars/Vascular_Atlas_ATT_Results.csv')
tmp_vascular_att
# Out:
#            mri_id                territory  mean_att  median_att  smoothing
# 0      BMRI817697                 Left_ACA  1.175599    1.184994          0
# 1      BMRI817697                Right_ACA  1.162422    1.163908          0
# 2      BMRI817697                 Left_MCA  1.205507    1.211579          0
# 3      BMRI817697                Right_MCA  1.199488    1.215463          0
# 4      BMRI817697                 Left_PCA  1.300860    1.296352          0
# ...           ...                      ...       ...         ...        ...
# 30289    IA553807             Left_Basilar  1.004291    1.013988          0
# 30290    IA553807            Right_Basilar  0.997359    1.011045          0
# 30291    IA553807   Left_Lateral_Ventricle       NaN         NaN          0
# 30292    IA553807  Right_Lateral_Ventricle       NaN         NaN          0
# 30293    IA553807                Watershed  1.294408    1.281056          0
#
# [30294 rows x 5 columns]

# %%
db_vascular_att = tmp_vascular_att.pivot_table(
    index='mri_id',
    columns=['territory', 'smoothing'],
    values='mean_att',
    aggfunc='mean'
)

# Flatten the MultiIndex columns to match your 'roi-s' format
db_vascular_att.columns = [f"{col[0]}-{col[1]}" for col in db_vascular_att.columns]

# Add patient_id from db_asl_cerebral_perfusion that matches mri_id
db_vascular_att['mri_id'] = pd.Series(pd.NA)
mriid2pesaid = {row['mri_id']: row.name for _, row in db_vascular_att.iterrows()}
db_vascular_att['patient_id'] = db_vascular_att.index.map(mriid2pesaid)
db_vascular_att
# Out:
#             Left_ACA-0  Left_ACA-8  Left_Basilar-0  Left_Basilar-8  \
# mri_id
# BMRI100102    1.321472    1.307595        1.147594        1.191484
# BMRI101198    1.215924    1.211927        1.067423        1.127502
# BMRI101846    1.218692    1.224967        1.120560        1.146782
# BMRI103891    1.196845    1.199444        1.083689        1.056860
# BMRI104117    1.247098    1.241798        1.028491        1.081847
# ...                ...         ...             ...             ...
# IA992381      1.242252         NaN        1.139954             NaN
# IA992548      1.212339    1.210406        1.143548        1.164324
# IA992747      1.296953         NaN        1.214247             NaN
# IA997088      1.279917    1.279951        1.284146        1.300130
# IA997404      1.265064         NaN        1.206381             NaN
#
#             Left_MCA-0  Left_MCA-8  Left_PCA-0  Left_PCA-8  Right_ACA-0  \
# mri_id
# BMRI100102    1.292698    1.257407    1.279656    1.274163     1.326077
# BMRI101198    1.185932    1.159482    1.193117    1.181748     1.252450
# BMRI101846    1.198390    1.194125    1.251637    1.248673     1.254652
# BMRI103891    1.228141    1.196905    1.199995    1.184765     1.221991
# BMRI104117    1.229464    1.202719    1.207225    1.199603     1.299853
# ...                ...         ...         ...         ...          ...
# IA992381      1.247923         NaN    1.222281         NaN     1.290695
# IA992548      1.188538    1.173346    1.216447    1.210323     1.204341
# IA992747      1.274713         NaN    1.289638         NaN     1.267015
# IA997088      1.290146    1.271367    1.353465    1.348354     1.313286
# IA997404      1.242816         NaN    1.218763         NaN     1.287085
#
#             Right_ACA-8  Right_Basilar-0  Right_Basilar-8  Right_MCA-0  \
# mri_id
# BMRI100102     1.306505         1.203652         1.232433     1.342529
# BMRI101198     1.237313         1.070519         1.131663     1.200591
# BMRI101846     1.251706         1.116226         1.142862     1.226417
# BMRI103891     1.215238         1.080799         1.098318     1.235333
# BMRI104117     1.275169         1.092258         1.130283     1.264362
# ...                 ...              ...              ...          ...
# IA992381            NaN         1.088242              NaN     1.302105
# IA992548       1.203485         1.130107         1.139551     1.202342
# IA992747            NaN         1.142644              NaN     1.283588
# IA997088       1.301619         1.218157         1.254569     1.298997
# IA997404            NaN         1.185890              NaN     1.264677
#
#             Right_MCA-8  Right_PCA-0  Right_PCA-8  Watershed-0  Watershed-8
# mri_id
# BMRI100102     1.303386     1.304759     1.294799     1.427158     1.381764
# BMRI101198     1.169922     1.224271     1.213519     1.304880     1.258934
# BMRI101846     1.213873     1.263052     1.256602     1.389370     1.359014
# BMRI103891     1.206449     1.194945     1.186462     1.300105     1.272074
# BMRI104117     1.237684     1.230974     1.218980     1.361692     1.313963
# ...                 ...          ...          ...          ...          ...
# IA992381            NaN     1.189071          NaN     1.340656          NaN
# IA992548       1.180840     1.205240     1.200708     1.313706     1.292106
# IA992747            NaN     1.276735          NaN     1.397564          NaN
# IA997088       1.274551     1.318106     1.318711     1.419589     1.380779
# IA997404            NaN     1.199641          NaN     1.342318          NaN
#
# [1438 rows x 18 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/gpu-nvitk/lib/python3.11/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mri_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 12
#      10 print(db_vascular_att)
#      11 # Add patient_id from db_asl_cerebral_perfusion that matches mri_id
# ---> 12 mriid2pesaid = {row['mri_id']: row.name for _, row in db_vascular_att.iterrows()}
#      13 db_vascular_att['patient_id'] = db_vascular_att.index.map(mriid2pesaid)
#      14 db_vascular_att
#
# Cell In[5], line 12, in <dictcomp>(.0)
#      10 print(db_vascular_att)
#      11 # Add patient_id from db_asl_cerebral_perfusion that matches mri_id
# ---> 12 mriid2pesaid = {row['mri_id']: row.name for _, row in db_vascular_att.iterrows()}
#      13 db_vascular_att['patient_id'] = db_vascular_att.index.map(mriid2pesaid)
#      14 db_vascular_att
#
# File ~/miniforge3/envs/gpu-nvitk/lib/python3.11/site-packages/pandas/core/series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File ~/miniforge3/envs/gpu-nvitk/lib/python3.11/site-packages/pandas/core/series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File ~/miniforge3/envs/gpu-nvitk/lib/python3.11/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'mri_id'
